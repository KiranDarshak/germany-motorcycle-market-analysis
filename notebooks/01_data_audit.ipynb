# %% [markdown]
# # Step 1 – Data Audit & Profiling
#
# This notebook performs an initial audit of the German motorcycle registration dataset.
# The goal is to understand:
# - Schema and data types
# - Grain of the data
# - Missing values and duplicates
# - Time coverage
#
# No transformations are applied in this step.

# %%
# %pip install pandas numpy matplotlib duckdb pyarrow
# Out:
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (2.3.3)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (2.2.6)
# Requirement already satisfied: matplotlib in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (3.10.8)
# Requirement already satisfied: duckdb in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (1.4.4)
# Requirement already satisfied: pyarrow in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (23.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/kirandarshak/Library/Python/3.10/lib/python/site-packages (from pandas) (2025.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# 2️⃣ Imports & file discovery

# %%
import pandas as pd
import numpy as np
import duckdb
import matplotlib.pyplot as plt
from pathlib import Path

print("All imports OK ✅")
# Out:
# All imports OK ✅

# %% [markdown]
# 3️⃣ Load the dataset

# %%
DATA_PATH = Path("../data/raw")
csv_files = list(DATA_PATH.glob("*.csv"))

csv_files
# Out:
# [PosixPath('../data/raw/SP_Hersteller_Handelsnamen_Krad_f73ec_-2904598668132282746.csv')]

# %%
CSV_FILE = csv_files[0]
df = pd.read_csv(CSV_FILE)

df.shape
# Out:
# (128719, 8)

# %% [markdown]
# 4️⃣ Preview the data

# %%
df.head(5)
# Out:
#   Report_date     Manufacturer Trade_name Type_key                State  \
# 0  01.01.2023  AEON MOTOR (RC)                 AAB   Schleswig-Holstein
# 1  01.01.2023  AEON MOTOR (RC)                 AAB        Niedersachsen
# 2  01.01.2023  AEON MOTOR (RC)                 AAB               Bremen
# 3  01.01.2023  AEON MOTOR (RC)                 AAB  Nordrhein-Westfalen
# 4  01.01.2023  AEON MOTOR (RC)                 AAB               Hessen
#
#    Count  ZS Anzahl  Object_Id
# 0      7        NaN          1
# 1     23        NaN          2
# 2      1        NaN          3
# 3      6        NaN          4
# 4     12        NaN          5

# %% [markdown]
# 5️⃣ Column names & schema

# %%
df.columns
# Out:
# Index(['Report_date', 'Manufacturer', 'Trade_name', 'Type_key', 'State',
#        'Count', 'ZS Anzahl', 'Object_Id'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128719 entries, 0 to 128718
# Data columns (total 8 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Report_date   128719 non-null  object
#  1   Manufacturer  128719 non-null  object
#  2   Trade_name    128430 non-null  object
#  3   Type_key      128719 non-null  object
#  4   State         128719 non-null  object
#  5   Count         128719 non-null  int64
#  6   ZS Anzahl     0 non-null       float64
#  7   Object_Id     128719 non-null  int64
# dtypes: float64(1), int64(2), object(5)
# memory usage: 7.9+ MB

# %% [markdown]
# 6️⃣ Missing values

# %%
missing = df.isna().sum().sort_values(ascending=False)
missing[missing > 0]
# Out:
# ZS Anzahl     128719
# Trade_name       289
# dtype: int64

# %% [markdown]
# 7️⃣ Duplicate rows

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# 8️⃣ Cardinality check

# %%
df.nunique().sort_values(ascending=False)
# Out:
# Object_Id       128719
# Count             2210
# Trade_name        2162
# Type_key           747
# Manufacturer        83
# State               17
# Report_date          3
# ZS Anzahl            0
# dtype: int64

# %% [markdown]
# 9️⃣ Detect date/time column

# %%
date_like = []

for c in df.columns:
    sample = df[c].dropna().astype(str).head(50)
    if len(sample) and sample.str.contains(r"\d{4}[-./]\d{2}").mean() > 0.6:
        date_like.append(c)

date_like
# Out:
# []

# %% [markdown]
# 1️⃣0️⃣ Basic stats for numeric fields

# %%
df.describe(include="number").T
# Out:
#               count          mean           std  min      25%      50%  \
# Count      128719.0    116.260428    845.897952  1.0      7.0     22.0
# ZS Anzahl       0.0           NaN           NaN  NaN      NaN      NaN
# Object_Id  128719.0  64360.000000  37158.118987  1.0  32180.5  64360.0
#
#                75%       max
# Count         69.0   56232.0
# ZS Anzahl      NaN       NaN
# Object_Id  96539.5  128719.0

# %%
import pandas as pd
import duckdb
from pathlib import Path

PROJECT_ROOT = Path("..")
RAW_PATH = PROJECT_ROOT / "data" / "raw"
DB_PATH = PROJECT_ROOT / "data" / "duckdb" / "motorcycle.db"

csv_files = list(RAW_PATH.glob("*.csv"))
CSV_FILE = csv_files[0]

CSV_FILE, DB_PATH
# Out:
# (PosixPath('../data/raw/SP_Hersteller_Handelsnamen_Krad_f73ec_-2904598668132282746.csv'),
#  PosixPath('../data/duckdb/motorcycle.db'))

# %%
con = duckdb.connect(str(DB_PATH))

# %%
con.close()
