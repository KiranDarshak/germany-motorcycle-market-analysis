# %% [markdown]
# # Step 2 – Ingestion (Bronze) into DuckDB
#
# Goal:
# - Load the raw CSV into DuckDB as a `raw_registrations` table
# - Keep data as-is (no business transformations yet)
# - Create a persistent DuckDB database file for the whole project

# %% [markdown]
# 2) Imports + paths

# %%
import pandas as pd
import duckdb
from pathlib import Path

PROJECT_ROOT = Path("..")
RAW_PATH = PROJECT_ROOT / "data" / "raw"
DB_PATH = PROJECT_ROOT / "data" / "duckdb" / "motorcycle.db"

csv_files = list(RAW_PATH.glob("*.csv"))
CSV_FILE = csv_files[0]

CSV_FILE, DB_PATH
# Out:
# (PosixPath('../data/raw/SP_Hersteller_Handelsnamen_Krad_f73ec_-2904598668132282746.csv'),
#  PosixPath('../data/duckdb/motorcycle.db'))

# %% [markdown]
# 3) Quick check: inspect Report_date format

# %%
df_sample = pd.read_csv(CSV_FILE, nrows=20)
df_sample["Report_date"].head(10).tolist()
# Out:
# ['01.01.2023',
#  '01.01.2023',
#  '01.01.2023',
#  '01.01.2023',
#  '01.01.2023',
#  '01.01.2023',
#  '01.01.2023',
#  '01.01.2023',
#  '01.01.2023',
#  '01.01.2023']

# %% [markdown]
# 4) Create DuckDB DB + load raw table

# %%
con = duckdb.connect(str(DB_PATH))

# Drop & recreate for repeatability during development
con.execute("DROP TABLE IF EXISTS raw_registrations")

con.execute(f"""
CREATE TABLE raw_registrations AS
SELECT * FROM read_csv_auto('{CSV_FILE.as_posix()}');
""")

con.execute("SELECT COUNT(*) FROM raw_registrations").fetchone()
# Out:
# (128719,)

# %% [markdown]
# 5) Confirm schema & preview

# %%
con.execute("DESCRIBE raw_registrations").fetchdf()
# Out:
#     column_name column_type null   key default extra
# 0   Report_date        DATE  YES  None    None  None
# 1  Manufacturer     VARCHAR  YES  None    None  None
# 2    Trade_name     VARCHAR  YES  None    None  None
# 3      Type_key     VARCHAR  YES  None    None  None
# 4         State     VARCHAR  YES  None    None  None
# 5         Count      BIGINT  YES  None    None  None
# 6     ZS Anzahl     VARCHAR  YES  None    None  None
# 7     Object_Id      BIGINT  YES  None    None  None

# %%
con.execute("SELECT * FROM raw_registrations LIMIT 5").fetchdf()
# Out:
#   Report_date     Manufacturer Trade_name Type_key                State  \
# 0  2023-01-01  AEON MOTOR (RC)                 AAB   Schleswig-Holstein
# 1  2023-01-01  AEON MOTOR (RC)                 AAB        Niedersachsen
# 2  2023-01-01  AEON MOTOR (RC)                 AAB               Bremen
# 3  2023-01-01  AEON MOTOR (RC)                 AAB  Nordrhein-Westfalen
# 4  2023-01-01  AEON MOTOR (RC)                 AAB               Hessen
#
#    Count ZS Anzahl  Object_Id
# 0      7      None          1
# 1     23      None          2
# 2      1      None          3
# 3      6      None          4
# 4     12      None          5

# %% [markdown]
# 6) Basic quality checks

# %%
# Null counts per column (quick)
con.execute("""
SELECT
  SUM(CASE WHEN Report_date IS NULL THEN 1 ELSE 0 END) AS null_report_date,
  SUM(CASE WHEN Manufacturer IS NULL THEN 1 ELSE 0 END) AS null_manufacturer,
  SUM(CASE WHEN State IS NULL THEN 1 ELSE 0 END) AS null_state,
  SUM(CASE WHEN Count IS NULL THEN 1 ELSE 0 END) AS null_count
FROM raw_registrations
""").fetchdf()
# Out:
#    null_report_date  null_manufacturer  null_state  null_count
# 0               0.0                0.0         0.0         0.0

# %%
# Top rows by Count to spot weird values
con.execute("""
SELECT Report_date, State, Manufacturer, Trade_name, Type_key, Count, "ZS Anzahl", Object_Id
FROM raw_registrations
ORDER BY Count DESC
LIMIT 10
""").fetchdf()
# Out:
#   Report_date                State         Manufacturer  \
# 0  2025-01-01               Bayern  SONSTIGE HERSTELLER
# 1  2024-01-01               Bayern  SONSTIGE HERSTELLER
# 2  2023-01-01               Bayern  SONSTIGE HERSTELLER
# 3  2025-01-01  Nordrhein-Westfalen  SONSTIGE HERSTELLER
# 4  2024-01-01  Nordrhein-Westfalen  SONSTIGE HERSTELLER
# 5  2025-01-01               Bayern          PIAGGIO (I)
# 6  2023-01-01  Nordrhein-Westfalen           YAMAHA (J)
# 7  2023-01-01  Nordrhein-Westfalen  SONSTIGE HERSTELLER
# 8  2024-01-01               Bayern          PIAGGIO (I)
# 9  2023-01-01               Bayern          PIAGGIO (I)
#
#               Trade_name Type_key  Count ZS Anzahl  Object_Id
# 0                                  56232      None     116809
# 1                                  55688      None      73851
# 2                                  54292      None      32626
# 3                                  41712      None     116805
# 4                                  41559      None      73835
# 5  SONSTIGE/NICHT GETYPT           40229      None     111285
# 6  SONSTIGE/NICHT GETYPT           40171      None      36867
# 7                                  40053      None      32614
# 8  SONSTIGE/NICHT GETYPT           39950      None      71444
# 9  SONSTIGE/NICHT GETYPT           39524      None      28778

# %%
# Check if Object_Id is unique (useful for dedupe)
con.execute("""
SELECT
  COUNT(*) AS rows,
  COUNT(DISTINCT Object_Id) AS distinct_object_id
FROM raw_registrations
""").fetchdf()
# Out:
#      rows  distinct_object_id
# 0  128719              128719

# %%
con.close()

# %%
con.execute("SHOW TABLES").fetchdf()
# Out:
#                             name
# 0                       dim_date
# 1                 dim_date_keyed
# 2               dim_manufacturer
# 3         dim_manufacturer_keyed
# 4                      dim_model
# 5                dim_model_keyed
# 6                      dim_state
# 7                dim_state_keyed
# 8              fct_registrations
# 9      mart_market_share_monthly
# 10             mart_model_pareto
# 11        mart_seasonality_index
# 12  mart_state_manufacturer_rank
# 13  mart_yoy_growth_manufacturer
# 14             raw_registrations
# 15             stg_registrations
# 16       stg_registrations_clean
# 17              vw_registrations

# %%
con.execute("""
SELECT Report_date, COUNT(*) AS rows
FROM silver_registrations_clean
GROUP BY Report_date
ORDER BY Report_date
""").fetchdf()
# Out:
# ---------------------------------------------------------------------------
# CatalogException                          Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 con.execute("""
#       2 SELECT Report_date, COUNT(*) AS rows
#       3 FROM silver_registrations_clean
#       4 GROUP BY Report_date
#       5 ORDER BY Report_date
#       6 """).fetchdf()
#
# CatalogException: Catalog Error: Table with name silver_registrations_clean does not exist!
# Did you mean "stg_registrations_clean"?
#
# LINE 3: FROM silver_registrations_clean
#              ^
